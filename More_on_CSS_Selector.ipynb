# %%
# Question 1 : Q1. For the given index.html file. Perform the following task, without changing the index.html file. index.html (The HTML file) A. Create a CSS file to apply styles to the HTML element, and link it B. Using the combinator selector, perform the following task `_ Use any of the CSS combinator selectors to target all the anchor tags and change the text color to re[ _ Target only the first <h2> tag and change the text and background color using the combinator selectol _ Also, select the first <p> tag and change the text color to red. C. Using the attribute selector, perform the following tas b_ target the anchor tag with attribute "href" and change color to red and remove the text underline¢ _ Target the anchor tag with the attribute of class name “active”, change the text color, and provide the text style properties with underlining _ Target the anchor tag with the attribute of the target whose value is “_self” and change the background color. D. Using the Pseudo selectors, perform the following tas _ Target the last <p> tag and add “...” i.e. three dots after its valuÆ _ Target the list of bullet points and change the color of the bullet points without changing the list item's value _ Among the three <p> tags target the 2nd <p> tag, select the first letter of the second <p> tag, and change the color to red Also increase the font size to 30px





/* Linking the CSS file */






-->
 /* B. Using combinator selectors */
/* Target all anchor tags and change text color to red */
body a {
    color: red;
}

/* Target only the first h2 tag and change text and background color */
body h2:first-of-type {
    color: white;
    background-color: blue;
}

/* Select the first p tag and change text color to red */
body p:first-of-type {
    color: red;
}

/* C. Using attribute selectors */
/* Target anchor tag with attribute "href" and change color, remove underline */
a[href] {
    color: red;
    text-decoration: none;
}

/* Target anchor tag with class "active", change text color, add underline */
a[class="active"] {
    color: green;
    text-decoration: underline;
}

/* Target anchor tag with target attribute value "_self" and change background color */
a[target="_self"] {
    background-color: yellow;
}

/* D. Using Pseudo selectors */
/* Target last <p> tag and add "..." after its value */
p:last-of-type::after {
    content: "...";
}

/* Change bullet point color without changing text */
li::marker {
    color: blue;
}

/* Target the second <p> tag, change first letter color and size */
p:nth-of-type(2)::first-letter {
    color: red;
    font-size: 30px;

# %%
# Question 2 : Q2.  Create a CSS file and link it to the provided HTML file below, use any of the combinator class selectors to style the navigation menu as follows - index.html (The HTML file) ` Use the Descendant combinator selector to remove list style type bullet points and text underlining of the Menu list itemse ` Use the child combinator to display the menu list item inlin^ ` Use the Adjacent sibling combinator selector to apply some margin between the menu list items. Note - the above HTML code should not be changed and you are not allowed to add any class name to the HTML file.

--> /* Styling the navigation menu */

/* Use the Descendant combinator selector to remove list style type bullet points and text underlining */
nav ul li {
    list-style-type: none;
}

nav ul li a {
    text-decoration: none;
}

/* Use the child combinator to display the menu list item inline */
nav > ul > li {
    display: inline;
    margin-right: 10px;
}

/* Use the Adjacent sibling combinator selector to apply some margin between the menu list items */
nav ul li + li {
    margin-left: 15px;
}

# %%
# Question 3 :  Using any of the Pseudo element selectors, add any random words after and before the given HTML tag

--> /* Styling the navigation menu */

/* Use the Descendant combinator selector to remove list style type bullet points and text underlining */
nav ul li {
    list-style-type: none;
}

nav ul li a {
    text-decoration: none;
}

/* Use the child combinator to display the menu list item inline */
nav > ul > li {
    display: inline;
    margin-right: 10px;
}

/* Use the Adjacent sibling combinator selector to apply some margin between the menu list items */
nav ul li + li {
    margin-left: 15px;
}

/* Q3: Using Pseudo Element Selectors to Add Text Before and After an HTML Tag */
.target-element::before {
    content: "[Before Text] ";
    color: gray;
    font-weight: bold;
}

.target-element::after {
    content: " [After Text]";
    color: gray;
    font-weight: bold;
}

# %%
# Question 4 : Q4. Using any of the Pseudo element selectors, add any random words after and before the given HTML tag Assignment Question | An example should be one HTML button tac | When hovering the color should be changed and the shadow of the button should be added^ | Proper padding space should be given^ | The cursor style should also be changed to a pointer on hover


--> /* Styling the navigation menu */

/* Use the Descendant combinator selector to remove list style type bullet points and text underlining */
nav ul li {
    list-style-type: none;
}

nav ul li a {
    text-decoration: none;
}

/* Use the child combinator to display the menu list item inline */
nav > ul > li {
    display: inline;
    margin-right: 10px;
}

/* Use the Adjacent sibling combinator selector to apply some margin between the menu list items */
nav ul li + li {
    margin-left: 15px;
}

/* Q3: Using Pseudo Element Selectors to Add Text Before and After an HTML Tag */
.target-element::before {
    content: "[Before Text] ";
    color: gray;
    font-weight: bold;
}

.target-element::after {
    content: " [After Text]";
    color: gray;
    font-weight: bold;
}

/* Q4: Styling the Button with Pseudo Elements and Hover Effects */
.button::before {
    content: "Click Here: ";
    font-weight: bold;
    color: blue;
}

.button::after {
    content: " ✅";
    color: green;
}

.button {
    padding: 10px 20px;
    border: none;
    background-color: lightgray;
    cursor: pointer;
    transition: all 0.3s ease;
}

.button:hover {
    background-color: darkgray;
    box-shadow: 2px 2px 5px rgba(0, 0, 0, 0.3);
}
